# %%
import os.path
import re
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.animation
from matplotlib.animation import FuncAnimation
import yt
import glob
import pandas as pd
import math
from matplotlib.backends.backend_pdf import PdfPages
import postprocessing
mpl.rcParams['figure.dpi'] = 100
# Out:
# /home/dbeckers/.conda/envs/postprocessing_v2/lib/python3.9/site-packages/yt/utilities/logger.py:4: VisibleDeprecationWarning: The configuration file /home/dbeckers/.config/yt/ytrc is deprecated in favor of /home/dbeckers/.config/yt/yt.toml. Currently, both are present. Please manually remove the deprecated one to silence this warning.
# Deprecated since v4.0.0. This feature will be removed in v4.1.0
#   from yt.config import ytcfg

# %%
yt.set_log_level(50)

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
dir_godunov_ppm = '/scratch/dbeckers/synth_turb/godunov_ppm/fine_to_coarse_small_50_50_10_restart/nx_100'
dir_mol_central = '/scratch/dbeckers/synth_turb/mol_central/fine_to_coarse_small_50_50_10_restart/nx_100'

# %%
def init_animation():
    return

# %%
# %%capture
plt.rcParams["animation.html"] = "jshtml"

fig,ax = plt.subplots()
ds = postprocessing.load_plt(dir_godunov_ppm,0)
slp = postprocessing.setup_slice_plot(fig,ax,ds,'boxlib','velocityy',[-0.5,0.5],center=(25,0,0),width=(50,'cm'))
# slp.annotate_cell_edges(line_width=0.0001)


def animate(i):
    ds = postprocessing.load_plt(dir_godunov_ppm,2*i)
    postprocessing.set_slice_data(slp,ds)

    return

anim = FuncAnimation(fig, animate, frames=24, interval=200)

# %%
anim
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %%
anim.save('synth_turb_godunov_ppm_50_50_10_nx_100_less_frames.gif',dpi=300)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %%
# %%capture
plt.rcParams["animation.html"] = "jshtml"

fig,ax = plt.subplots()
ds = postprocessing.load_plt(dir_mol_central,0)
slp = postprocessing.setup_slice_plot(fig,ax,ds,'boxlib','velocityy',[-0.5,0.5],center=(25,0,0),width=(50,'cm'))
# slp.annotate_cell_edges(line_width=0.0001)


def animate(i):
    ds = postprocessing.load_plt(dir_mol_central,2*i)
    postprocessing.set_slice_data(slp,ds)

    return

anim = FuncAnimation(fig, animate, frames=24, interval=200)

# %%
anim.save('synth_turb_mol_central_50_50_10_nx_100_less_frames.gif',dpi=300)
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.

# %%
fig,ax = plt.subplots()
ds = postprocessing.load_plt(dir_godunov_ppm,0)
slp = postprocessing.setup_slice_plot(fig,ax,ds,'boxlib','velocityy',[-0.5,0.5],buff_size=[4000,4000],center=(25,0,0),width=(50,'cm'))
slp.annotate_cell_edges(line_width=0.0001)
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
# slp.save('synth_turb_initial_frame_with_grid.png')
# Out:
# ['synth_turb_initial_frame_with_grid.png']

# %%
fig,ax = plt.subplots()
ds = postprocessing.load_plt(dir_mol_central,0)
slp = postprocessing.setup_slice_plot(fig,ax,ds,'boxlib','velocityy',[-0.5,0.5])
slp.annotate_grids()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
fig,ax = plt.subplots()
ds = postprocessing.load_plt(root_dir,10)
slp = postprocessing.setup_slice_plot(fig,ax,ds,'boxlib','velocityx',[0,2])
slp.annotate_grids()
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
fig,ax = plt.subplots()
ds = postprocessing.load_plt(root_dir,0)
slp = postprocessing.setup_slice_plot(fig,ax,ds,'boxlib','velocityx',[0,2],buff_size=[4000,4000])
slp.annotate_cell_edges(line_width=0.0001)
slp.set_figure_size(10)
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
ds.field_info
# Out:
# {('boxlib',
#   'density'): On-Disk Field (boxlib, density): (units: code_mass / code_length**3),
#  ('gas',
#   'density'): Alias Field for "('boxlib', 'density')" (gas, density): (units: g/cm**3),
#  ('boxlib', 'gpx'): On-Disk Field (boxlib, gpx): (units: ),
#  ('boxlib', 'gpy'): On-Disk Field (boxlib, gpy): (units: ),
#  ('boxlib', 'gpz'): On-Disk Field (boxlib, gpz): (units: ),
#  ('boxlib', 'p'): On-Disk Field (boxlib, p): (units: ),
#  ('boxlib', 'q_criterion'): On-Disk Field (boxlib, q_criterion): (units: ),
#  ('boxlib',
#   'synth_turb_forcingx'): On-Disk Field (boxlib, synth_turb_forcingx): (units: ),
#  ('boxlib',
#   'synth_turb_forcingy'): On-Disk Field (boxlib, synth_turb_forcingy): (units: ),
#  ('boxlib',
#   'synth_turb_forcingz'): On-Disk Field (boxlib, synth_turb_forcingz): (units: ),
#  ('boxlib', 'velocityx'): On-Disk Field (boxlib, velocityx): (units: ),
#  ('boxlib', 'velocityy'): On-Disk Field (boxlib, velocityy): (units: ),
# ...
